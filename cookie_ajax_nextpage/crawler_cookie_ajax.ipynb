# %% [markdown]
# ## 基本爬蟲 : 文章標題、作者、時間...

# %%
import requests

# %%
url = 'https://www.ptt.cc/bbs/Soft_Job/index.html'

response = requests.get(url)
# print(response.text)

#把respone寫成html
if response.status_code == 200:
  with open('output.html','w', encoding='utf-8') as f:
    f.write(response.text)
  print('寫入成功')
else:
  print('沒抓到網頁')
# Out:
# 寫入成功

# %% [markdown]
# - 反爬蟲
# > 常見方法 : 檢查請求的 Header ( 偽裝成使用者 )、輸入驗證碼、滑動解鎖

# %%
#檢查請求的 Header
url = 'https://www.ptt.cc/bbs/Soft_Job/index.html'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'}

response = requests.get(url, headers=headers)

with open('output.html','w', encoding='utf-8') as f:
  f.write(response.text)

# %% [markdown]
# - 使用 BeautifulSoup 解析網頁
# > BeautifulSoup 可分析 HTML 或 XML ，也可拿來修復未閉合標籤等錯誤文件。
# - 輸出 json 格式

# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
import json

url = 'https://www.ptt.cc/bbs/Soft_Job/index.html'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'}
response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, 'html.parser')
articles = soup.find_all('div', class_='r-ent')
data_list = []

for a in articles:
  data = {}
  title = a.find('div', class_='title')
  if title and title.a:  #確認文章是否存在
    title = title.a.text
  else:
    title = 'title not found'
  data['標題'] = title

  popular = a.find('div', class_='nrec')
  if popular and popular.span:
    popular = popular.span.text
  else:
    popular = 'N/A'
  data['人氣'] = popular

  date = a.find('div', class_='date')
  if date:
    date = date.text
  else:
    date = 'N/A'
  data['日期'] = date

  data_list.append(data)

# print(data_list)
with open('ptt_soft_data.json','w', encoding='utf-8') as f:
    #將資料轉換
    json.dump(data_list, f, ensure_ascii=False, indent=4)  #indent:縮排
print('資料儲存成功 ptt_soft_data.json')

  # print(f'標題: {title} 人氣: {popular} 日期: {date}')
# Out:
# 資料儲存成功 ptt_soft_data.json

# %% [markdown]
# - 輸出 excel 格式

# %%
# !pip install openpyxl

# %%
import pandas as pd

df = pd.DataFrame(data_list)
df.to_excel('ptt_soft.xlsx', index=False, engine='openpyxl')  #excel更容易閱讀、和做資料分析

# %% [markdown]
# ## 偽裝 cookie、圖片下載
# 撰寫爬蟲的第一步是**觀察網頁它是如何取得資料的** !
# - 爬蟲需使用 cookie 偽裝成使用者
# > 進入網站前會先經過成年確認，透過 f12 開啟 network 可發現其中狀態碼為 302 ( 重新導向 )。進入 application 中進一步觀察 cookie。
# - 將文章中的圖片下載

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.ptt.cc/bbs/Beauty/M.1686997472.A.FDA.html'

headers = {'Cookie':'over18=1'}
response = requests.get(url, headers=headers)  #加上cookie
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    [正妹] 張景嵐 - 看板 Beauty - 批踢踢實業坊
#   </title>
#   <meta content="all" name="robots"/>
#   <meta content="Ptt BBS 批踢踢" name="keywords"/>
#   <meta content="https://i.imgur.com/eT8ofhi.jpg
# https://i.imgur.com/OJrUPbr.jpg
# https://i.imgur.com/MrZUajC.jpg
# https://i.imgur.com/RrNJt1y.jpg
# https://i.imgur.com/YGx57uU.jpg
# " name="description"/>
#   <meta content="Ptt 批踢踢實業坊" property="og:site_name"/>
#   <meta content="[正妹] 張景嵐" property="og:title"/>
#   <meta content="https://i.imgur.com/eT8ofhi.jpg
# https://i.imgur.com/OJrUPbr.jpg
# https://i.imgur.com/MrZUajC.jpg
# https://i.imgur.com/RrNJt1y.jpg
# https://i.imgur.com/YGx57uU.jpg
# " property="og:description"/>
#   <link href="https://www.ptt.cc/bbs/Beauty/M.1686997472.A.FDA.html" rel="canonical"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/bbs/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
#     <a class="board" href="/bbs/Beauty/index.html">
#      <span class="board-label">
#       看板
#      </span>
#      Beauty
#     </a>
#     <a class="right small" href="/about.html">
#      關於我們
#     </a>
#     <a class="right small" href="/contact.html">
#      聯絡資訊
#     </a>
#    </div>
#   </div>
#   <div id="navigation-container">
#    <div class="bbs-content" id="navigation">
#     <a class="board" href="/bbs/Beauty/index.html">
#      返回看板
#     </a>
#     <div class="bar">
#     </div>
#    </div>
#   </div>
#   <div id="main-container">
#    <div class="bbs-screen bbs-content" id="main-content">
#     <div class="article-metaline">
#      <span class="article-meta-tag">
#       作者
#      </span>
#      <span class="article-meta-value">
#       iwjwlmsc0707 (JEFF HSU)
#      </span>
#     </div>
#     <div class="article-metaline-right">
#      <span class="article-meta-tag">
#       看板
#      </span>
#      <span class="article-meta-value">
#       Beauty
#      </span>
#     </div>
#     <div class="article-metaline">
#      <span class="article-meta-tag">
#       標題
#      </span>
#      <span class="article-meta-value">
#       [正妹] 張景嵐
#      </span>
#     </div>
#     <div class="article-metaline">
#      <span class="article-meta-tag">
#       時間
#      </span>
#      <span class="article-meta-value">
#       Sat Jun 17 18:24:28 2023
#      </span>
#     </div>
#     <a href="https://i.imgur.com/eT8ofhi.jpg" rel="noreferrer noopener nofollow" target="_blank">
#      https://i.imgur.com/eT8ofhi.jpg
#     </a>
#     <div class="richcontent">
#      <img alt="" loading="lazy" src="https://cache.ptt.cc/c/https/i.imgur.com/eT8ofhil.jpg?e=1707707277&amp;s=ZsjKbrssuTr4rgLd_vUpqA"/>
#     </div>
#     <a href="https://i.imgur.com/OJrUPbr.jpg" rel="noreferrer noopener nofollow" target="_blank">
#      https://i.imgur.com/OJrUPbr.jpg
#     </a>
#     <div class="richcontent">
#      <img alt="" loading="lazy" src="https://cache.ptt.cc/c/https/i.imgur.com/OJrUPbrl.jpg?e=1707731412&amp;s=GeNXj6MIra6r_BDmhEntzA"/>
#     </div>
#     <a href="https://i.imgur.com/MrZUajC.jpg" rel="noreferrer noopener nofollow" target="_blank">
#      https://i.imgur.com/MrZUajC.jpg
#     </a>
#     <div class="richcontent">
#      <img alt="" loading="lazy" src="https://cache.ptt.cc/c/https/i.imgur.com/MrZUajCl.jpg?e=1707674366&amp;s=f67WfMCpqAQOSi0rtRMUuA"/>
#     </div>
#     <a href="https://i.imgur.com/RrNJt1y.jpg" rel="noreferrer noopener nofollow" target="_blank">
#      https://i.imgur.com/RrNJt1y.jpg
#     </a>
#     <div class="richcontent">
#      <img alt="" loading="lazy" src="https://cache.ptt.cc/c/https/i.imgur.com/RrNJt1yl.jpg?e=1707727042&amp;s=w6e6YIL7NrJJpoNTrXLzag"/>
#     </div>
#     <a href="https://i.imgur.com/YGx57uU.jpg" rel="noreferrer noopener nofollow" target="_blank">
#      https://i.imgur.com/YGx57uU.jpg
#     </a>
#     <div class="richcontent">
#      <img alt="" loading="lazy" src="https://cache.ptt.cc/c/https/i.imgur.com/YGx57uUl.jpg?e=1707714034&amp;s=x9FCnlPJI0hdwedtm5UrBA"/>
#     </div>
#     <a href="https://i.imgur.com/EaKmudk.jpg" rel="noreferrer noopener nofollow" target="_blank">
#      https://i.imgur.com/EaKmudk.jpg
#     </a>
#     <div class="richcontent">
#      <img alt="" loading="lazy" src="https://cache.ptt.cc/c/https/i.imgur.com/EaKmudkl.jpg?e=1707714364&amp;s=B9mH-654VtbnEziZt_szNA"/>
#     </div>
#     景嵐姊姊 你真的好漂亮
# -----
# Sent from JPTT on my iPhone
#
# --
#     <span class="f2">
#      ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 1.174.23.87 (臺灣)
#     </span>
#     <span class="f2">
#      ※ 文章網址:
#      <a href="https://www.ptt.cc/bbs/Beauty/M.1686997472.A.FDA.html" rel="noreferrer noopener nofollow" target="_blank">
#       https://www.ptt.cc/bbs/Beauty/M.1686997472.A.FDA.html
#      </a>
#     </span>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       aa607752
#      </span>
#      <span class="f3 push-content">
#       : 樓下張景嵐
#      </span>
#      <span class="push-ipdatetime">
#       223.139.63.78 06/17 18:25
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       ps006575
#      </span>
#      <span class="f3 push-content">
#       : 最近沒啥作品，沉寂一段時間了
#      </span>
#      <span class="push-ipdatetime">
#       42.76.98.184 06/17 18:25
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       噓
#      </span>
#      <span class="f3 hl push-userid">
#       foucault1984
#      </span>
#      <span class="f3 push-content">
#       : 可惜了精緻的外表
#      </span>
#      <span class="push-ipdatetime">
#       123.193.165.101 06/17 18:27
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       qazwsx0123q
#      </span>
#      <span class="f3 push-content">
#       : 專心在事業上
#      </span>
#      <span class="push-ipdatetime">
#       223.137.82.197 06/17 18:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       ePaper
#      </span>
#      <span class="f3 push-content">
#       : 超讚 個人覺得是林志玲後最讚的
#      </span>
#      <span class="push-ipdatetime">
#       116.241.163.109 06/17 18:34
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       GodMune0608
#      </span>
#      <span class="f3 push-content">
#       : 樓下景嵐
#      </span>
#      <span class="push-ipdatetime">
#       140.112.248.220 06/17 18:35
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       lai101011
#      </span>
#      <span class="f3 push-content">
#       : 我不是 樓下才是ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       42.72.80.125 06/17 18:39
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Simonfenix
#      </span>
#      <span class="f3 push-content">
#       : 至少要到半夜本人才會出現吧
#      </span>
#      <span class="push-ipdatetime">
#       223.138.0.149 06/17 18:43
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       gto5310099
#      </span>
#      <span class="f3 push-content">
#       : 有氣質 又超正
#      </span>
#      <span class="push-ipdatetime">
#       39.15.66.187 06/17 18:46
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       YuyangChen
#      </span>
#      <span class="f3 push-content">
#       : 我婆謝謝
#      </span>
#      <span class="push-ipdatetime">
#       1.161.220.177 06/17 18:49
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ashilol
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       49.216.23.29 06/17 18:51
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       TenRings
#      </span>
#      <span class="f3 push-content">
#       : 真的很漂亮
#      </span>
#      <span class="push-ipdatetime">
#       180.217.28.14 06/17 18:54
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sv1423
#      </span>
#      <span class="f3 push-content">
#       : 吃這麼油
#      </span>
#      <span class="push-ipdatetime">
#       101.8.8.144 06/17 19:00
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       espresso1
#      </span>
#      <span class="f3 push-content">
#       : 樓下景嵐
#      </span>
#      <span class="push-ipdatetime">
#       101.10.2.226 06/17 19:02
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       smart1989
#      </span>
#      <span class="f3 push-content">
#       : 我不是 樓下才是景嵐
#      </span>
#      <span class="push-ipdatetime">
#       42.73.93.111 06/17 19:09
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       s008866
#      </span>
#      <span class="f3 push-content">
#       : 我不是 樓下才是chinlan
#      </span>
#      <span class="push-ipdatetime">
#       223.141.160.212 06/17 19:10
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       AyakaIV
#      </span>
#      <span class="f3 push-content">
#       : 我不是 樓下才是chinlan
#      </span>
#      <span class="push-ipdatetime">
#       36.236.124.218 06/17 19:13
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       keroming
#      </span>
#      <span class="f3 push-content">
#       : 金蘭~金蘭~~
#      </span>
#      <span class="push-ipdatetime">
#       36.230.91.252 06/17 19:14
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       噓
#      </span>
#      <span class="f3 hl push-userid">
#       yushenglu
#      </span>
#      <span class="f3 push-content">
#       : 感恩師父讚嘆師父 我寧願幹陳菊
#      </span>
#      <span class="push-ipdatetime">
#       111.82.36.190 06/17 19:16
#      </span>
#     </div>
#     你去啊 沒人攔你
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       cityhunter04
#      </span>
#      <span class="f3 push-content">
#       : D槽內的她超正
#      </span>
#      <span class="push-ipdatetime">
#       114.24.70.18 06/17 19:17
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       YakultSlime
#      </span>
#      <span class="f3 push-content">
#       : 事業感覺很賺
#      </span>
#      <span class="push-ipdatetime">
#       220.137.117.140 06/17 19:17
#      </span>
#     </div>
#     <span class="f2">
#      ※ 編輯: iwjwlmsc0707 (1.174.23.87 臺灣), 06/17/2023 19:17:30
#     </span>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       噓
#      </span>
#      <span class="f3 hl push-userid">
#       andy199113
#      </span>
#      <span class="f3 push-content">
#       : 老
#      </span>
#      <span class="push-ipdatetime">
#       118.160.146.242 06/17 19:24
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       lgates
#      </span>
#      <span class="f3 push-content">
#       : 居然還沒有銳寶貝出現
#      </span>
#      <span class="push-ipdatetime">
#       61.61.171.158 06/17 19:29
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       a904472000
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       223.139.78.172 06/17 19:35
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       birdpon
#      </span>
#      <span class="f3 push-content">
#       : 我比較喜歡邵雨薇
#      </span>
#      <span class="push-ipdatetime">
#       123.50.53.192 06/17 19:36
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       GoruGo831
#      </span>
#      <span class="f3 push-content">
#       : 樓下才是ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       49.216.51.33 06/17 19:43
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       chanceiam
#      </span>
#      <span class="f3 push-content">
#       : 我不是
#      </span>
#      <span class="push-ipdatetime">
#       59.115.161.132 06/17 19:45
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ooJACKYoo
#      </span>
#      <span class="f3 push-content">
#       : 主持澳洲旅遊節目但不會英文的主持人
#      </span>
#      <span class="push-ipdatetime">
#       223.137.102.78 06/17 19:45
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       amare1015
#      </span>
#      <span class="f3 push-content">
#       : 吃這麼油 還是她念起來最色 &gt;&lt;
#      </span>
#      <span class="push-ipdatetime">
#       111.251.191.242 06/17 19:46
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       噓
#      </span>
#      <span class="f3 hl push-userid">
#       ooJACKYoo
#      </span>
#      <span class="f3 push-content">
#       : 補噓
#      </span>
#      <span class="push-ipdatetime">
#       223.137.102.78 06/17 19:47
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       johnwu
#      </span>
#      <span class="f3 push-content">
#       : 還是超正的 完全可以
#      </span>
#      <span class="push-ipdatetime">
#       123.195.117.241 06/17 19:47
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ayazard
#      </span>
#      <span class="f3 push-content">
#       : 口條有變好了嗎？
#      </span>
#      <span class="push-ipdatetime">
#       111.255.234.94 06/17 20:08
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       dogcatking
#      </span>
#      <span class="f3 push-content">
#       : 在我樓下
#      </span>
#      <span class="push-ipdatetime">
#       223.137.10.134 06/17 20:18
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       imanonymous
#      </span>
#      <span class="f3 push-content">
#       : 我心中的正妹前三名
#      </span>
#      <span class="push-ipdatetime">
#       123.192.182.122 06/17 20:20
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       just888
#      </span>
#      <span class="f3 push-content">
#       : 召喚野生景嵐
#      </span>
#      <span class="push-ipdatetime">
#       1.200.241.97 06/17 20:21
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       DareJ
#      </span>
#      <span class="f3 push-content">
#       : 你講話小心會被咪兔
#      </span>
#      <span class="push-ipdatetime">
#       36.225.55.153 06/17 20:23
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       cobras638
#      </span>
#      <span class="f3 push-content">
#       : 召喚野生景嵐
#      </span>
#      <span class="push-ipdatetime">
#       114.45.11.192 06/17 20:24
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       fox0315
#      </span>
#      <span class="f3 push-content">
#       : 還是很正啊
#      </span>
#      <span class="push-ipdatetime">
#       111.253.125.177 06/17 20:26
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Krishna
#      </span>
#      <span class="f3 push-content">
#       : 晚餐決定吃海鮮了
#      </span>
#      <span class="push-ipdatetime">
#       123.193.251.73 06/17 20:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       johnny721009
#      </span>
#      <span class="f3 push-content">
#       : 見面不如聞名
#      </span>
#      <span class="push-ipdatetime">
#       27.53.129.63 06/17 20:30
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       wayne070283
#      </span>
#      <span class="f3 push-content">
#       : 景嵐一生推
#      </span>
#      <span class="push-ipdatetime">
#       42.73.121.55 06/17 20:31
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       mutecr
#      </span>
#      <span class="f3 push-content">
#       : 樓下才是ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       36.227.109.228 06/17 20:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Harionago
#      </span>
#      <span class="f3 push-content">
#       : 好漂釀
#      </span>
#      <span class="push-ipdatetime">
#       114.43.137.27 06/17 20:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       aaaa8247
#      </span>
#      <span class="f3 push-content">
#       : 真的很可愛
#      </span>
#      <span class="push-ipdatetime">
#       218.161.63.103 06/17 20:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       GBDog
#      </span>
#      <span class="f3 push-content">
#       : 樓下本尊
#      </span>
#      <span class="push-ipdatetime">
#       203.204.98.251 06/17 20:37
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       mai11iw3250
#      </span>
#      <span class="f3 push-content">
#       : 妙禪的形狀
#      </span>
#      <span class="push-ipdatetime">
#       49.216.19.58 06/17 20:42
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       turnoff11
#      </span>
#      <span class="f3 push-content">
#       : 台灣最正，沒人比得上
#      </span>
#      <span class="push-ipdatetime">
#       1.164.1.161 06/17 20:48
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       eusttass
#      </span>
#      <span class="f3 push-content">
#       : 樓下景嵐
#      </span>
#      <span class="push-ipdatetime">
#       114.136.195.20 06/17 20:50
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jamescle23
#      </span>
#      <span class="f3 push-content">
#       : 超正
#      </span>
#      <span class="push-ipdatetime">
#       114.136.67.154 06/17 20:52
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       game636610
#      </span>
#      <span class="f3 push-content">
#       : 樓下景嵐暗戀我很久了，只是害羞不敢
#      </span>
#      <span class="push-ipdatetime">
#       111.255.25.199 06/17 20:55
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       game636610
#      </span>
#      <span class="f3 push-content">
#       : 表白
#      </span>
#      <span class="push-ipdatetime">
#       111.255.25.199 06/17 20:55
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       n613011
#      </span>
#      <span class="f3 push-content">
#       : 樓下野生ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       125.231.170.184 06/17 20:56
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jay0055846
#      </span>
#      <span class="f3 push-content">
#       : 正
#      </span>
#      <span class="push-ipdatetime">
#       49.159.214.171 06/17 21:04
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       BruceChen227
#      </span>
#      <span class="f3 push-content">
#       : 樓下本人
#      </span>
#      <span class="push-ipdatetime">
#       111.242.183.38 06/17 21:04
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       rea1
#      </span>
#      <span class="f3 push-content">
#       : seafood
#      </span>
#      <span class="push-ipdatetime">
#       1.164.3.44 06/17 21:10
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       aoyama
#      </span>
#      <span class="f3 push-content">
#       : 超逆天的～ 美
#      </span>
#      <span class="push-ipdatetime">
#       180.217.159.60 06/17 21:11
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       bobon0921
#      </span>
#      <span class="f3 push-content">
#       : 樓下景嵐
#      </span>
#      <span class="push-ipdatetime">
#       203.77.43.26 06/17 21:16
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       takaminaoto
#      </span>
#      <span class="f3 push-content">
#       : 嫁給我
#      </span>
#      <span class="push-ipdatetime">
#       61.56.167.8 06/17 21:18
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       highka1003
#      </span>
#      <span class="f3 push-content">
#       : 嗯～最愛壞壞的銳寶貝
#      </span>
#      <span class="push-ipdatetime">
#       111.80.147.113 06/17 21:18
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       peter211183
#      </span>
#      <span class="f3 push-content">
#       : 樓下張景嵐
#      </span>
#      <span class="push-ipdatetime">
#       223.140.144.155 06/17 21:19
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       j900414
#      </span>
#      <span class="f3 push-content">
#       : 我老婆
#      </span>
#      <span class="push-ipdatetime">
#       101.12.26.87 06/17 21:22
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       GMQQQ
#      </span>
#      <span class="f3 push-content">
#       : 景嵐姐姐，為什麼你都沒有變老，始終如一&gt;&lt;
#      </span>
#      <span class="push-ipdatetime">
#       118.231.138.53 06/17 21:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       GMQQQ
#      </span>
#      <span class="f3 push-content">
#       : 每次PO就妙禪妙禪的推文煩不煩==
#      </span>
#      <span class="push-ipdatetime">
#       118.231.138.53 06/17 21:30
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       wglhe
#      </span>
#      <span class="f3 push-content">
#       : 吃這麼油真的好看
#      </span>
#      <span class="push-ipdatetime">
#       42.77.55.59 06/17 21:30
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       salvin
#      </span>
#      <span class="f3 push-content">
#       : 正
#      </span>
#      <span class="push-ipdatetime">
#       111.82.87.187 06/17 21:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       snake7222
#      </span>
#      <span class="f3 push-content">
#       : 管她妙不妙我都100分可以
#      </span>
#      <span class="push-ipdatetime">
#       180.217.78.147 06/17 21:36
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Xliao
#      </span>
#      <span class="f3 push-content">
#       : 難道要爆文才召喚的到ChinLan？
#      </span>
#      <span class="push-ipdatetime">
#       180.217.243.80 06/17 21:36
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       CTTSAI
#      </span>
#      <span class="f3 push-content">
#       : 僅存推文多的老人，現在年輕人都只看韓團
#      </span>
#      <span class="push-ipdatetime">
#       180.214.186.65 06/17 21:38
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       CTTSAI
#      </span>
#      <span class="f3 push-content">
#       : 了
#      </span>
#      <span class="push-ipdatetime">
#       180.214.186.65 06/17 21:38
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       leo589726
#      </span>
#      <span class="f3 push-content">
#       : 還是很正～！
#      </span>
#      <span class="push-ipdatetime">
#       111.251.28.156 06/17 21:40
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ivanww
#      </span>
#      <span class="f3 push-content">
#       : 國中買的那本寫真到現在還擺在床頭櫃上
#      </span>
#      <span class="push-ipdatetime">
#       124.6.10.125 06/17 21:52
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       si5111
#      </span>
#      <span class="f3 push-content">
#       : 樓下本人
#      </span>
#      <span class="push-ipdatetime">
#       101.8.13.213 06/17 21:55
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       oops66
#      </span>
#      <span class="f3 push-content">
#       : 不是 是樓下
#      </span>
#      <span class="push-ipdatetime">
#       123.194.95.19 06/17 21:59
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Demonic1013
#      </span>
#      <span class="f3 push-content">
#       : 哈哈ChinLan在我下面啦
#      </span>
#      <span class="push-ipdatetime">
#       223.136.33.35 06/17 22:06
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Hosh
#      </span>
#      <span class="f3 push-content">
#       : 讓他爆，我要看ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       42.73.51.67 06/17 22:06
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ganlinlowsu
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       1.200.29.117 06/17 22:11
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       calance
#      </span>
#      <span class="f3 push-content">
#       : 樓下...
#      </span>
#      <span class="push-ipdatetime">
#       27.240.224.58 06/17 22:14
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       cat123788
#      </span>
#      <span class="f3 push-content">
#       : 我不是，樓下才是
#      </span>
#      <span class="push-ipdatetime">
#       122.117.216.131 06/17 22:15
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       CCWchris
#      </span>
#      <span class="f3 push-content">
#       : 我不是樓下才是
#      </span>
#      <span class="push-ipdatetime">
#       101.12.90.26 06/17 22:18
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       EchoRyne
#      </span>
#      <span class="f3 push-content">
#       : 我不是 樓下才是
#      </span>
#      <span class="push-ipdatetime">
#       123.193.248.167 06/17 22:20
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       a30269228
#      </span>
#      <span class="f3 push-content">
#       : 樓下景嵐
#      </span>
#      <span class="push-ipdatetime">
#       111.83.90.118 06/17 22:21
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       shengkao
#      </span>
#      <span class="f3 push-content">
#       : 該出來了，樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       1.163.64.78 06/17 22:24
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       kennyhen
#      </span>
#      <span class="f3 push-content">
#       : 我不是，但這髮型不太適合她
#      </span>
#      <span class="push-ipdatetime">
#       1.160.237.99 06/17 22:27
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jacky647873
#      </span>
#      <span class="f3 push-content">
#       : 樓下景嵐
#      </span>
#      <span class="push-ipdatetime">
#       203.204.125.126 06/17 22:29
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       coolchichi
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan出來玩
#      </span>
#      <span class="push-ipdatetime">
#       114.44.2.35 06/17 22:29
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ylshpiliman
#      </span>
#      <span class="f3 push-content">
#       : 景嵐我老婆
#      </span>
#      <span class="push-ipdatetime">
#       114.26.137.6 06/17 22:29
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       willx
#      </span>
#      <span class="f3 push-content">
#       : 老婆ChinLan該出來見客了
#      </span>
#      <span class="push-ipdatetime">
#       150.117.200.43 06/17 22:29
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       UncleB
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       27.242.200.111 06/17 22:34
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       fanif
#      </span>
#      <span class="f3 push-content">
#       : 我也不是 樓下才是ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       223.136.81.20 06/17 22:37
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       pilor
#      </span>
#      <span class="f3 push-content">
#       : 我也不是 樓下才是ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       36.234.121.76 06/17 22:37
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       m6dj942k7
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       111.71.103.217 06/17 22:38
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sunnybread
#      </span>
#      <span class="f3 push-content">
#       : ChinLan ChinLan ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       42.72.91.18 06/17 22:39
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       SC30mvp
#      </span>
#      <span class="f3 push-content">
#       : 不是我 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       220.135.135.77 06/17 22:39
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       greenmaplex
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       1.200.56.171 06/17 22:39
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Broyz
#      </span>
#      <span class="f3 push-content">
#       : 太香了，就算死會，始終第一名
#      </span>
#      <span class="push-ipdatetime">
#       39.9.162.43 06/17 22:43
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       two2
#      </span>
#      <span class="f3 push-content">
#       : 目前台灣檯面上最正，屌打其他人
#      </span>
#      <span class="push-ipdatetime">
#       223.140.187.53 06/17 22:43
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jet22662266
#      </span>
#      <span class="f3 push-content">
#       : 香
#      </span>
#      <span class="push-ipdatetime">
#       1.168.129.93 06/17 22:44
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ISNAKEI
#      </span>
#      <span class="f3 push-content">
#       : 我不是 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       101.8.10.125 06/17 22:44
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       drugash
#      </span>
#      <span class="f3 push-content">
#       : 暴力討債好帥
#      </span>
#      <span class="push-ipdatetime">
#       111.248.143.44 06/17 22:50
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       cacing1111
#      </span>
#      <span class="f3 push-content">
#       : 天啊好正好正
#      </span>
#      <span class="push-ipdatetime">
#       36.229.215.189 06/17 22:55
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       GGSCII
#      </span>
#      <span class="f3 push-content">
#       : 人正但是講話超級吵的
#      </span>
#      <span class="push-ipdatetime">
#       123.192.82.47 06/17 22:56
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jerryyuan
#      </span>
#      <span class="f3 push-content">
#       : 她講話改善不少了 最近也很少出現吧
#      </span>
#      <span class="push-ipdatetime">
#       218.166.114.251 06/17 22:57
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       fcz973
#      </span>
#      <span class="f3 push-content">
#       : 曾經我的最愛，現在幾乎沒有曝光度了
#      </span>
#      <span class="push-ipdatetime">
#       123.195.149.222 06/17 22:58
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       roroccc
#      </span>
#      <span class="f3 push-content">
#       : 周曉涵、張景嵐2大40路女神
#      </span>
#      <span class="push-ipdatetime">
#       123.252.27.223 06/17 23:02
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       zoidswsaga
#      </span>
#      <span class="f3 push-content">
#       : 油切綠茶時期正爆
#      </span>
#      <span class="push-ipdatetime">
#       223.137.247.30 06/17 23:02
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       tahikuro
#      </span>
#      <span class="f3 push-content">
#       : 她才34 不到40
#      </span>
#      <span class="push-ipdatetime">
#       114.43.200.93 06/17 23:03
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       feng990719
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       111.253.239.76 06/17 23:04
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       a396216
#      </span>
#      <span class="f3 push-content">
#       : 女生漏奶是不是故意引發獸性
#      </span>
#      <span class="push-ipdatetime">
#       114.46.60.91 06/17 23:04
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ThomasWei919
#      </span>
#      <span class="f3 push-content">
#       : 樓下就是景嵐了，你各位不要一直que
#      </span>
#      <span class="push-ipdatetime">
#       27.52.73.155 06/17 23:07
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       ThomasWei919
#      </span>
#      <span class="f3 push-content">
#       : 我老婆好不好，晚上這樣子很煩欸
#      </span>
#      <span class="push-ipdatetime">
#       27.52.73.155 06/17 23:07
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Gardenia0603
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       36.227.234.3 06/17 23:08
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       winston99422
#      </span>
#      <span class="f3 push-content">
#       : 呼叫景嵐，想看本人上來留言
#      </span>
#      <span class="push-ipdatetime">
#       42.72.148.239 06/17 23:14
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       showmehe
#      </span>
#      <span class="f3 push-content">
#       : 我不是 樓下才是chinlan
#      </span>
#      <span class="push-ipdatetime">
#       42.73.243.178 06/17 23:15
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       miss80423
#      </span>
#      <span class="f3 push-content">
#       : 我婆
#      </span>
#      <span class="push-ipdatetime">
#       101.9.49.250 06/17 23:19
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jeff520
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       101.137.58.148 06/17 23:22
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       cccc77
#      </span>
#      <span class="f3 push-content">
#       : 樓下景嵐
#      </span>
#      <span class="push-ipdatetime">
#       1.171.101.82 06/17 23:24
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       rock0807
#      </span>
#      <span class="f3 push-content">
#       : 我是金城武  樓下才是ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       114.136.228.60 06/17 23:32
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Thompson13
#      </span>
#      <span class="f3 push-content">
#       : 樓下才是
#      </span>
#      <span class="push-ipdatetime">
#       1.200.47.248 06/17 23:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       HsinMichaelJ
#      </span>
#      <span class="f3 push-content">
#       : 等我啦 樓下景嵐
#      </span>
#      <span class="push-ipdatetime">
#       111.82.73.17 06/17 23:35
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       噓
#      </span>
#      <span class="f3 hl push-userid">
#       vgl
#      </span>
#      <span class="f3 push-content">
#       : 信妙禪失敗
#      </span>
#      <span class="push-ipdatetime">
#       39.9.36.95 06/17 23:45
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       RICEFINCH
#      </span>
#      <span class="f3 push-content">
#       : 喝茶花甩體脂
#      </span>
#      <span class="push-ipdatetime">
#       123.240.237.66 06/17 23:51
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       abc31216
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       223.140.25.238 06/17 23:51
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ko309491
#      </span>
#      <span class="f3 push-content">
#       : 景嵐我愛你
#      </span>
#      <span class="push-ipdatetime">
#       42.76.213.59 06/17 23:55
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       yaes111
#      </span>
#      <span class="f3 push-content">
#       : 樓下Chinlan
#      </span>
#      <span class="push-ipdatetime">
#       223.137.136.202 06/17 23:57
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       newsbow
#      </span>
#      <span class="f3 push-content">
#       : 可惜信妙禪
#      </span>
#      <span class="push-ipdatetime">
#       219.91.4.72 06/17 23:57
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       DDJwolf
#      </span>
#      <span class="f3 push-content">
#       : 這衣服是得罪人喔
#      </span>
#      <span class="push-ipdatetime">
#       42.76.249.197 06/18 00:03
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jerryyuan
#      </span>
#      <span class="f3 push-content">
#       : 原PO可惜 昨天凌晨有登入XD
#      </span>
#      <span class="push-ipdatetime">
#       218.166.114.251 06/18 00:09
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jerryyuan
#      </span>
#      <span class="f3 push-content">
#       : 爆
#      </span>
#      <span class="push-ipdatetime">
#       218.166.114.251 06/18 00:09
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       APC
#      </span>
#      <span class="f3 push-content">
#       : 褲子有點微妙
#      </span>
#      <span class="push-ipdatetime">
#       1.200.240.46 06/18 00:11
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       TuChinJui
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       59.115.75.252 06/18 00:12
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       tbs7melody
#      </span>
#      <span class="f3 push-content">
#       : 保健室解決
#      </span>
#      <span class="push-ipdatetime">
#       101.9.44.211 06/18 00:14
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       tbs7melody
#      </span>
#      <span class="f3 push-content">
#       : 姊姊*
#      </span>
#      <span class="push-ipdatetime">
#       101.9.44.211 06/18 00:14
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       drunk0102
#      </span>
#      <span class="f3 push-content">
#       : 我不是 樓下才是
#      </span>
#      <span class="push-ipdatetime">
#       39.10.41.13 06/18 00:17
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       kevinacc084
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       223.140.239.129 06/18 00:18
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       LPMO
#      </span>
#      <span class="f3 push-content">
#       : 我去叫一下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       112.78.70.35 06/18 00:20
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       FanHalen
#      </span>
#      <span class="f3 push-content">
#       : 推
#      </span>
#      <span class="push-ipdatetime">
#       49.216.162.252 06/18 00:25
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       giadruu
#      </span>
#      <span class="f3 push-content">
#       : 好的，我等等請我老婆上線
#      </span>
#      <span class="push-ipdatetime">
#       180.217.194.81 06/18 00:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Jawei99
#      </span>
#      <span class="f3 push-content">
#       : 景嵐真的美個性也可愛
#      </span>
#      <span class="push-ipdatetime">
#       27.247.74.129 06/18 00:32
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       QQ5566
#      </span>
#      <span class="f3 push-content">
#       : 紫衣沒救了
#      </span>
#      <span class="push-ipdatetime">
#       113.165.167.225 06/18 00:39
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       AmazingAFU
#      </span>
#      <span class="f3 push-content">
#       : 上過景嵐的節目 本人超級無敵好 很健
#      </span>
#      <span class="push-ipdatetime">
#       180.217.197.220 06/18 00:41
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       AmazingAFU
#      </span>
#      <span class="f3 push-content">
#       : 談很有趣大推
#      </span>
#      <span class="push-ipdatetime">
#       180.217.197.220 06/18 00:41
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Eriecho
#      </span>
#      <span class="f3 push-content">
#       : 樓下本人
# ...
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       KSUGOD
#      </span>
#      <span class="f3 push-content">
#       : 嵐姐正很久 SG到現在
#      </span>
#      <span class="push-ipdatetime">
#       1.173.201.176 06/18 23:44
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sam1304
#      </span>
#      <span class="f3 push-content">
#       : 樓下景甜
#      </span>
#      <span class="push-ipdatetime">
#       61.227.30.110 06/19 00:11
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       y6yv3r4d
#      </span>
#      <span class="f3 push-content">
#       : 接力召喚
#      </span>
#      <span class="push-ipdatetime">
#       1.171.185.231 06/19 00:15
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       CmPunk666
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan！
#      </span>
#      <span class="push-ipdatetime">
#       101.139.76.245 06/19 01:16
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       oxlittle
#      </span>
#      <span class="f3 push-content">
#       : ChinLan 不看表特版了嗎
#      </span>
#      <span class="push-ipdatetime">
#       1.171.18.76 06/19 03:35
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       leo589726
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan 兩天了 該出現了吧
#      </span>
#      <span class="push-ipdatetime">
#       1.171.84.33 06/19 04:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       big111
#      </span>
#      <span class="f3 push-content">
#       : 女神 推
#      </span>
#      <span class="push-ipdatetime">
#       223.137.131.233 06/19 08:13
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       噓
#      </span>
#      <span class="f3 hl push-userid">
#       cl1030hen
#      </span>
#      <span class="f3 push-content">
#       : 笑死 下面一堆在酸她的 怎麼可能現身
#      </span>
#      <span class="push-ipdatetime">
#       36.230.73.97 06/19 11:32
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       senyufresh
#      </span>
#      <span class="f3 push-content">
#       : 我嵐超正
#      </span>
#      <span class="push-ipdatetime">
#       49.217.64.93 06/19 12:46
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       leedonsee
#      </span>
#      <span class="f3 push-content">
#       : 好 樓下景嵐 謝謝
#      </span>
#      <span class="push-ipdatetime">
#       223.137.188.59 06/19 16:23
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ajcky
#      </span>
#      <span class="f3 push-content">
#       : 旬果好正~
#      </span>
#      <span class="push-ipdatetime">
#       122.121.40.218 06/19 17:27
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       dd8818ois
#      </span>
#      <span class="f3 push-content">
#       : 欸那個要找個高雄林志玲的 趕快去
#      </span>
#      <span class="push-ipdatetime">
#       27.53.154.91 06/19 17:55
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       finn138159
#      </span>
#      <span class="f3 push-content">
#       : 永遠的顏值擔當
#      </span>
#      <span class="push-ipdatetime">
#       39.10.8.185 06/19 20:04
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       s70076
#      </span>
#      <span class="f3 push-content">
#       : ChinLan出來打球了
#      </span>
#      <span class="push-ipdatetime">
#       27.242.68.153 06/19 22:24
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       flyway
#      </span>
#      <span class="f3 push-content">
#       : 真正的女神
#      </span>
#      <span class="push-ipdatetime">
#       114.25.78.129 06/19 23:48
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       fatdaddy
#      </span>
#      <span class="f3 push-content">
#       : 我天天都有乖乖喝
#      </span>
#      <span class="push-ipdatetime">
#       114.36.119.195 06/20 01:05
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       av8d2124
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan，繼續接力
#      </span>
#      <span class="push-ipdatetime">
#       42.74.197.62 06/20 02:15
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       dennis02
#      </span>
#      <span class="f3 push-content">
#       : 還是紫衣的形狀嗎？QQ
#      </span>
#      <span class="push-ipdatetime">
#       223.136.129.82 06/20 08:29
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       s930120hung
#      </span>
#      <span class="f3 push-content">
#       : 樓下ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       203.204.148.188 06/20 08:43
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       kb24leo
#      </span>
#      <span class="f3 push-content">
#       : 景嵐姐姐一生推
#      </span>
#      <span class="push-ipdatetime">
#       36.231.137.49 06/20 10:48
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       chungzu
#      </span>
#      <span class="f3 push-content">
#       : 要乖乖喝喔
#      </span>
#      <span class="push-ipdatetime">
#       61.216.178.93 06/20 15:23
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       theta4719
#      </span>
#      <span class="f3 push-content">
#       : 我不是 樓下是
#      </span>
#      <span class="push-ipdatetime">
#       101.8.40.231 06/20 20:38
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ray36
#      </span>
#      <span class="f3 push-content">
#       : 樓上不是，樓下才是ChinLan
#      </span>
#      <span class="push-ipdatetime">
#       114.47.31.156 06/20 23:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ChinLan
#      </span>
#      <span class="f3 push-content">
#       : 我來了大家！抱歉久等了～
#      </span>
#      <span class="push-ipdatetime">
#       223.137.136.233 06/21 15:48
#      </span>
#     </div>
#     恭迎姊姊降臨
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jonasj
#      </span>
#      <span class="f3 push-content">
#       : 樓上我老婆
#      </span>
#      <span class="push-ipdatetime">
#       125.231.118.224 06/21 16:10
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       shinicr
#      </span>
#      <span class="f3 push-content">
#       : 樓上景嵐
#      </span>
#      <span class="push-ipdatetime">
#       114.136.105.216 06/21 16:12
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       a8813q
#      </span>
#      <span class="f3 push-content">
#       : 朝聖推
#      </span>
#      <span class="push-ipdatetime">
#       42.79.128.120 06/21 16:50
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       jerryyuan
#      </span>
#      <span class="f3 push-content">
#       : 景嵐在上面
#      </span>
#      <span class="push-ipdatetime">
#       1.173.53.15 06/21 18:20
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Scent56
#      </span>
#      <span class="f3 push-content">
#       : 朝聖
#      </span>
#      <span class="push-ipdatetime">
#       14.192.208.77 06/21 18:38
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       s70076
#      </span>
#      <span class="f3 push-content">
#       : 終於召喚出本人了
#      </span>
#      <span class="push-ipdatetime">
#       27.52.164.137 06/21 22:25
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       winston99422
#      </span>
#      <span class="f3 push-content">
#       : 朝聖 本人來留言了
#      </span>
#      <span class="push-ipdatetime">
#       42.72.236.78 06/22 00:35
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       iifz32
#      </span>
#      <span class="f3 push-content">
#       : 笑死哈哈
#      </span>
#      <span class="push-ipdatetime">
#       118.232.30.158 06/22 07:18
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       zxccxz12345
#      </span>
#      <span class="f3 push-content">
#       : 朝聖本人
#      </span>
#      <span class="push-ipdatetime">
#       223.136.226.123 06/22 07:39
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       vul3cp4dd
#      </span>
#      <span class="f3 push-content">
#       : 沒想到竟然有本人
#      </span>
#      <span class="push-ipdatetime">
#       219.85.44.190 06/22 09:21
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       eric8i01
#      </span>
#      <span class="f3 push-content">
#       : 朝聖
#      </span>
#      <span class="push-ipdatetime">
#       220.137.156.107 06/22 11:38
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       OCDisorder
#      </span>
#      <span class="f3 push-content">
#       : 推景嵐回應了
#      </span>
#      <span class="push-ipdatetime">
#       111.184.41.121 06/22 12:31
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       VRmax
#      </span>
#      <span class="f3 push-content">
#       : 景嵐太美了！
#      </span>
#      <span class="push-ipdatetime">
#       1.200.24.201 06/22 17:44
#      </span>
#     </div>
#     <span class="f2">
#      ※ 編輯: iwjwlmsc0707 (1.174.0.89 臺灣), 06/22/2023 19:51:01
#     </span>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       STimmy
#      </span>
#      <span class="f3 push-content">
#       : 真的來了XDDD
#      </span>
#      <span class="push-ipdatetime">
#       42.79.244.137 06/22 21:57
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       cokelime
#      </span>
#      <span class="f3 push-content">
#       : 召喚到本人了我還不再推一個XD
#      </span>
#      <span class="push-ipdatetime">
#       220.136.202.59 06/23 03:51
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ChangHash
#      </span>
#      <span class="f3 push-content">
#       : 景嵐妹妹真的是穠纖合度的代表
#      </span>
#      <span class="push-ipdatetime">
#       124.218.75.172 06/23 08:59
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       be5566
#      </span>
#      <span class="f3 push-content">
#       : 姐姐多大了
#      </span>
#      <span class="push-ipdatetime">
#       220.134.194.142 06/25 10:43
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Jayferrari
#      </span>
#      <span class="f3 push-content">
#       : 老婆別亂回鄉民的文章
#      </span>
#      <span class="push-ipdatetime">
#       49.217.197.173 06/26 15:27
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       GMQQQ
#      </span>
#      <span class="f3 push-content">
#       : 大家要召喚講話好聽一點...,又酸又要召喚人
#      </span>
#      <span class="push-ipdatetime">
#       39.14.10.84 06/26 18:14
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       GMQQQ
#      </span>
#      <span class="f3 push-content">
#       : 家很給面子了
#      </span>
#      <span class="push-ipdatetime">
#       39.14.10.84 06/26 18:14
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ilsr
#      </span>
#      <span class="f3 push-content">
#       : 腿是極品，但紫衣+銳寶貝就算了
#      </span>
#      <span class="push-ipdatetime">
#       116.59.104.82 06/30 10:26
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       howard03
#      </span>
#      <span class="f3 push-content">
#       : 推本人
#      </span>
#      <span class="push-ipdatetime">
#       36.224.207.13 06/30 23:18
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       yushiung
#      </span>
#      <span class="f3 push-content">
#       : 朝聖 老婆來了
#      </span>
#      <span class="push-ipdatetime">
#       67.168.114.18 09/28 10:19
#      </span>
#     </div>
#    </div>
#    <div data-longpollurl="/v1/longpoll?id=c8e1c4575541969809e9e2187ec37373825ee4f1" data-offset="30308" data-pollurl="/poll/Beauty/M.1686997472.A.FDA.html?cacheKey=2148-616595998&amp;offset=30308&amp;offset-sig=3c6c77c08011a6ed03ab060aaf5fe9e89d32afd0" id="article-polling">
#    </div>
#    <div class="bbs-screen bbs-footer-message">
#     本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#    </div>
#   </div>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js">
#   </script>
#   <script src="//images.ptt.cc/bbs/v2.27/bbs.js">
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"85340ed02a60ab97","version":"2024.2.1","r":1,"token":"515615eb5fab4c9b91a11e9bf529e6cf","b":1}' defer="" integrity="sha512-euoFGowhlaLqXsPWQ48qSkBSCFs3DPRyiwVu3FjR96cMPx+Fr+gpWRhIafcHwqwCqWS42RZhIudOvEI+Ckf6MA==" src="https://static.cloudflareinsights.com/beacon.min.js/v84a3a4012de94ce1a686ba8c167c359c1696973893317">
#   </script>
#  </body>
# </html>

# %%
spans = soup.find_all('span', class_='article-meta-value')  #因為span可能有多個，所以使用find_all方法
print(spans)
print(spans[2])
print(spans[2].text)
# Out:
# [<span class="article-meta-value">iwjwlmsc0707 (JEFF HSU)</span>, <span class="article-meta-value">Beauty</span>, <span class="article-meta-value">[正妹] 張景嵐</span>, <span class="article-meta-value">Sat Jun 17 18:24:28 2023</span>]
# <span class="article-meta-value">[正妹] 張景嵐</span>
# [正妹] 張景嵐

# %%
import os

title = spans[2].text
dir_name = f'images/{title}'  #建立用來儲存圖片的資料夾
if not os.path.exists(dir_name):
  os.makedirs(dir_name)  #建立資料夾

# %%
links = soup.find_all('a')  #找到網頁中的所有連結
allow_file_name = ['jpg','png','jpeg','gif']
for link in links:
  href = link.get('href')
  extention = href.split('.')[-1].lower()  #取得副檔名
  if extention in allow_file_name:
    print(f'file: {extention}')
    print(f'url: {href}')
  if not href:
    continue  #跳過
  # print(href)
# Out:
# file: jpg
# url: https://i.imgur.com/eT8ofhi.jpg
# file: jpg
# url: https://i.imgur.com/OJrUPbr.jpg
# file: jpg
# url: https://i.imgur.com/MrZUajC.jpg
# file: jpg
# url: https://i.imgur.com/RrNJt1y.jpg
# file: jpg
# url: https://i.imgur.com/YGx57uU.jpg
# file: jpg
# url: https://i.imgur.com/EaKmudk.jpg

# %%
#將上述抓取圖片的內容整合
import requests
from bs4 import BeautifulSoup
import os


def main():
  url = 'https://www.ptt.cc/bbs/Beauty/M.1686997472.A.FDA.html'

  headers = {'Cookie':'over18=1'}
  response = requests.get(url, headers=headers)
  soup = BeautifulSoup(response.text, 'html.parser')
  spans = soup.find_all('span', class_='article-meta-value')

  title = spans[2].text
  dir_name = f'images/{title}'
  if not os.path.exists(dir_name):
    os.makedirs(dir_name)

  links = soup.find_all('a')
  allow_file_name = ['jpg','png','jpeg','gif']
  for link in links:
    href = link.get('href')
    if not href:
      continue  #跳過
    file_name = href.split('/')[-1]
    extention = href.split('.')[-1].lower()
    if extention in allow_file_name:
      print(f'file: {extention}')
      print(f'url: {href}')
      download_img(href, f'{dir_name}/{file_name}')


def download_img(url, save_path):
  print(f'正在下載圖片: {url}')
  response = requests.get(url)
  with open(save_path, 'wb') as file:  #因為要儲存圖片所以使用'wb'，b代表二進位(binary)
    file.write(response.content)
  print('-'*30)


#如果此程式作為主要的執行，才會觸發main()
if __name__ == '__main__':
  main()
# Out:
# file: jpg
# url: https://i.imgur.com/eT8ofhi.jpg
# 正在下載圖片: https://i.imgur.com/eT8ofhi.jpg
# ------------------------------
# file: jpg
# url: https://i.imgur.com/OJrUPbr.jpg
# 正在下載圖片: https://i.imgur.com/OJrUPbr.jpg
# ------------------------------
# file: jpg
# url: https://i.imgur.com/MrZUajC.jpg
# 正在下載圖片: https://i.imgur.com/MrZUajC.jpg
# ------------------------------
# file: jpg
# url: https://i.imgur.com/RrNJt1y.jpg
# 正在下載圖片: https://i.imgur.com/RrNJt1y.jpg
# ------------------------------
# file: jpg
# url: https://i.imgur.com/YGx57uU.jpg
# 正在下載圖片: https://i.imgur.com/YGx57uU.jpg
# ------------------------------
# file: jpg
# url: https://i.imgur.com/EaKmudk.jpg
# 正在下載圖片: https://i.imgur.com/EaKmudk.jpg
# ------------------------------

# %% [markdown]
# ## ajax 爬蟲
# AJAX即「Asynchronous JavaScript and XML」（非同步的JavaScript與XML技術），是 Web 應用程式開發技術的組合，可讓 Web 應用程式更快速地回應使用者互動。
# 1. 使用者訪問網址
# 2. 回傳 HTML ( 無資料 )
# 3. JS 發出 AJAX 請求
# 4. 伺服器回傳資料，JS 渲染畫面
#
# --> 我們需要知道瀏覽器中的 JavaScript 是透過哪幾支 API 獲得資料。
#
# --> 將我們需要的 api 網址貼到線上的 json formatter 中更好的觀察各個欄位。

# %%
import requests

url = 'https://api.hahow.in/api/products/search?category=COURSE&filter=PUBLISHED&limit=24&page=0&sort=TRENDING'
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
}
response = requests.get(url, headers=headers)
if response.status_code == 200:
  data = response.json()
  products = data['data']['courseData']['products']
  course_list = []
  for product in products:  #印出每個課程名稱
    course_data = [
        product['title'],
        product['averageRating'],
        product['price'],
        product['numSoldTickets']
    ]
    course_list.append(course_data)
  print(course_list)
else:
  print('無法取得網頁')
# Out:
# [['掌握鉤針編織邏輯：五種針法自造生活小物', 4.98, 2580, 3960], ['《電商群募流》電商人必學千萬銷售心法', 0, 7960, 761], ['戰爭來了怎麼辦？黑熊學院民防基礎線上課', 4.97, 2300, 3012], ['Notion 實戰課程：打造專屬數位工作術', 4.95, 3380, 11193], ['用 Python 理財：打造小資族選股策略', 4.96, 3200, 11747], ['產品設計實戰：用Figma打造絕佳UI/UX', 4.99, 4280, 7717], ['用戶x商業x數據 | UX‧三刀流產品體驗設計', 4.91, 3666, 1122], ['占星之門安格斯｜十二宮位找出人生攻略', 4.92, 2580, 3455], ['人人必修動力鏈-強化身體弱連結', 5, 4200, 2240], ['設計師接案學－業界求生必備守則', 4.96, 1800, 5379], ['讓插畫走入生活－Procreate 文創物實作！', 0, 2880, 1487], ['Python 入門特訓 - 基礎實作到證照攻略', 4.98, 1790, 5523], ['跟 YouTuber 莫彩曦學美國道地的說話習慣', 4.92, 1900, 29394], ['曾寶儀——從心開始的溝通術', 4.97, 1900, 1867], ['AI 時代人人必學：用 ChatGPT 全面升級你的工作流程', 4.8, 3280, 1205], ['邏輯表達力-周震宇的口語邏輯優化課', 4.96, 3680, 5274], ['Canva 入門到進階實戰｜零基礎做質感設計', 5, 2780, 1060], ['RyuuuTV看動漫看日劇，零到N4道地說日文', 4.97, 3500, 9196], ['聲入人心-周震宇的人聲必修課', 4.98, 3980, 8438], ['Excel 新手入門必修課：從 0 開始', 4.99, 990, 3568], ['直球對決你的工作焦慮！劉軒的 50 堂職場心理學', 5, 8000, 2027], ['電商人妻 IG 增粉攻略！三大領域經營術', 4.97, 3980, 5143], ['AutoCAD 電腦繪圖2D基礎篇－紮實入門', 4.96, 2500, 3671], ['4 間花店聯手打造的花藝課｜輕鬆培養第二專長', 4.94, 7980, 1881]]

# %%
import pandas

#用pandas儲存成excel時，每個資料須為一個列表
df = pd.DataFrame(course_list, columns=['課程名稱','評價','價格','購買人數'])
df.to_excel('course.xlsx', index=False, engine='openpyxl')

# %% [markdown]
# ## 電影爬蟲
# - 點擊下一頁

# %%
import requests
from bs4 import BeautifulSoup
import time

data_list = []

def fetch_data(url):
  requests.packages.urllib3.util.ssl_.DEFAULT_CIPHERS = 'DES-CBC3-SHA'
  response = requests.get(url, headers=headers)
  soup = BeautifulSoup(response.text, 'html.parser')
  movies = soup.find_all('div', class_='row movie-list bottommargin-sm')
  for movie in movies:
    name = movie.find('div', class_='col-md-10 col-sm-9')
    name = name.a.text.strip()  #strip可刪除開頭或結尾的多餘空格
    info = movie.find('ul', class_='entry-meta clearfix').find_all('li')  #找出所有li標籤
    date = info[0].text.replace('上映日期：', '').strip()
    length = info[1].text.replace('片長：', '').strip()
    view = info[3].text.replace('瀏覽人數：', '').strip()
    data_list.append([name, date, length, view])
  print(data_list)

  next_page = soup.find('ul', class_='pagination').find_all('li')[5]
  if next_page and next_page.a:
    next_url = next_page.a.get('href')
    print(f'正在爬取{next_url}')
    time.sleep(2)
    fetch_data('https://www.venice-cinemas.com.tw/movie.php'+next_url)


url = 'https://www.venice-cinemas.com.tw/movie.php?state=1&webpage=2'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'}
fetch_data(url)
# Out:
# [['還錢', '2024-02-08', '1時49分', '912人'], ['飛鴨向前衝', '2024-02-08', '1時32分', '502人'], ['小子', '2024-02-08', '1時41分', '599人'], ['青春養成記', '2024-02-08', '1時40分', '310人'], ['臨時劫案', '2024-02-08', '1時38分', '700人']]
# 正在爬取?state=1&page=2
# [['還錢', '2024-02-08', '1時49分', '912人'], ['飛鴨向前衝', '2024-02-08', '1時32分', '502人'], ['小子', '2024-02-08', '1時41分', '599人'], ['青春養成記', '2024-02-08', '1時40分', '310人'], ['臨時劫案', '2024-02-08', '1時38分', '700人'], ['鬼太郎誕生：咯咯咯之謎', '2024-02-07', '1時45分', '765人'], ['Fukuyama Masaharu Live Film Kotodama no Sakiwau Natsu Boy Meets The Music @Nippon Budokan 2023', '2024-02-06', '2時17分', '471人'], ['愛愛愛上你', '2024-02-02', '1時43分', '1,153人'], ['劇場版SPY × FAMILY 間諜家家酒CODE: White', '2024-02-02', '1時50分', '8,973人'], ['機密特務：阿蓋爾', '2024-01-31', '2時19分', '1,539人']]
# 正在爬取?state=1&page=3
# [['還錢', '2024-02-08', '1時49分', '912人'], ['飛鴨向前衝', '2024-02-08', '1時32分', '502人'], ['小子', '2024-02-08', '1時41分', '599人'], ['青春養成記', '2024-02-08', '1時40分', '310人'], ['臨時劫案', '2024-02-08', '1時38分', '700人'], ['鬼太郎誕生：咯咯咯之謎', '2024-02-07', '1時45分', '765人'], ['Fukuyama Masaharu Live Film Kotodama no Sakiwau Natsu Boy Meets The Music @Nippon Budokan 2023', '2024-02-06', '2時17分', '471人'], ['愛愛愛上你', '2024-02-02', '1時43分', '1,153人'], ['劇場版SPY × FAMILY 間諜家家酒CODE: White', '2024-02-02', '1時50分', '8,973人'], ['機密特務：阿蓋爾', '2024-01-31', '2時19分', '1,539人'], ['劇場版 轉生成女性向遊戲只有毀滅 END 的壞人大小姐', '2024-01-25', '1時33分', '599人'], ['光之美少女電影ALL STARS F', '2024-01-19', '1時13分', '693人'], ['潛行', '2024-01-19', '1時55分', '3,601人'], ['鬼聲泣', '2024-01-19', '2時01分', '3,165人'], ['窗邊的小荳荳', '2024-01-12', '1時54分', '1,387人']]
# 正在爬取?state=1&page=4
# [['還錢', '2024-02-08', '1時49分', '912人'], ['飛鴨向前衝', '2024-02-08', '1時32分', '502人'], ['小子', '2024-02-08', '1時41分', '599人'], ['青春養成記', '2024-02-08', '1時40分', '310人'], ['臨時劫案', '2024-02-08', '1時38分', '700人'], ['鬼太郎誕生：咯咯咯之謎', '2024-02-07', '1時45分', '765人'], ['Fukuyama Masaharu Live Film Kotodama no Sakiwau Natsu Boy Meets The Music @Nippon Budokan 2023', '2024-02-06', '2時17分', '471人'], ['愛愛愛上你', '2024-02-02', '1時43分', '1,153人'], ['劇場版SPY × FAMILY 間諜家家酒CODE: White', '2024-02-02', '1時50分', '8,973人'], ['機密特務：阿蓋爾', '2024-01-31', '2時19分', '1,539人'], ['劇場版 轉生成女性向遊戲只有毀滅 END 的壞人大小姐', '2024-01-25', '1時33分', '599人'], ['光之美少女電影ALL STARS F', '2024-01-19', '1時13分', '693人'], ['潛行', '2024-01-19', '1時55分', '3,601人'], ['鬼聲泣', '2024-01-19', '2時01分', '3,165人'], ['窗邊的小荳荳', '2024-01-12', '1時54分', '1,387人'], ['魔法公主', '2024-01-05', '2時13分', '2,807人'], ['金手指', '2023-12-30', '2時06分', '4,952人'], ['星願', '2023-12-29', '1時35分', '3,733人'], ['水行俠 失落王國', '2023-12-20', '2時04分', '5,521人'], ['可憐的東西', '2024-02-08', '2時21分', '574人']]

# %%
import pandas

df = pd.DataFrame(data_list, columns=['片名','上映日期','片長','觀看人數'])
df.to_excel('上映中.xlsx', index=False, engine='openpyxl')
